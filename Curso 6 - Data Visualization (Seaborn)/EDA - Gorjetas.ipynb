# %% [markdown]
# ## Importando a Base de Dados

# %%
import pandas as pd

# %%
pd.read_csv('tips.csv')
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %%
dados = pd.read_csv('tips.csv')
dados.head(5)
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %% [markdown]
# ## Tradução

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill' : 'valor_da_conta' , 
    'tip' : 'gorjeta',
    'dessert' : 'sobremesa',
    'day' : 'dia_da_semana',
    'time' : 'hora_do_dia',
    'size' : 'total_de_pessoas'
}

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas.head(4)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
# 1           10.34     1.66        No           Sun      Dinner
# 2           21.01     3.50        No           Sun      Dinner
# 3           23.68     3.31        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {'No' : 'Não' , 'Yes' : 'Sim'}

# %%
gorjetas.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head(20)
# Out:
#     valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0            16.99     1.01       Não           Sun      Dinner
# 1            10.34     1.66       Não           Sun      Dinner
# 2            21.01     3.50       Não           Sun      Dinner
# 3            23.68     3.31       Não           Sun      Dinner
# 4            24.59     3.61       Não           Sun      Dinner
# 5            25.29     4.71       Não           Sun      Dinner
# 6             8.77     2.00       Não           Sun      Dinner
# 7            26.88     3.12       Não           Sun      Dinner
# 8            15.04     1.96       Não           Sun      Dinner
# 9            14.78     3.23       Não           Sun      Dinner
# 10           10.27     1.71       Não           Sun      Dinner
# 11           35.26     5.00       Não           Sun      Dinner
# 12           15.42     1.57       Não           Sun      Dinner
# 13           18.43     3.00       Não           Sun      Dinner
# ...

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
    'Sun' : 'Domingo',
    'Sat' : 'Sábado',
    'Thur' : 'Quinta',
    'Fri' : 'Sexta'
}

# %%
gorjetas.dia_da_semana = gorjetas.dia_da_semana.map(dias)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Dinner
# 1           10.34     1.66       Não       Domingo      Dinner
# 2           21.01     3.50       Não       Domingo      Dinner
# 3           23.68     3.31       Não       Domingo      Dinner
# 4           24.59     3.61       Não       Domingo      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner' : 'Jantar', 
    'Lunch' : 'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas.head(5)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %% [markdown]
# ## Importando o SeaBorn

# %%
import seaborn as sns

# %%
sns.__version__ #ver a versão do seaborn
# Out:
# '0.11.1'

# %%
# !pip show seaborn #ver a versão do seaborn 2
# Out:
# Name: seaborn
# Version: 0.11.1
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: c:\users\dell inspiron\anaconda3\lib\site-packages
# Requires: scipy, numpy, matplotlib, pandas
# Required-by:
# ---
# Name: seaborn
# Version: 0.11.1
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: c:\users\dell inspiron\anaconda3\lib\site-packages
# Requires: scipy, numpy, matplotlib, pandas
# Required-by:
# WARNING: Package(s) not found: #ver, 2, a, do, versão

# %% [markdown]
# ## Análise 1 - Valor da Conta & Gorjeta

# %%
gorjetas.columns
# Out:
# Index(['valor_da_conta', 'gorjeta', 'sobremesa', 'dia_da_semana',
#        'hora_do_dia', 'total_de_pessoas'],
#       dtype='object')

# %%
valor_gorjeta = sns.scatterplot(x = 'valor_da_conta', y='gorjeta', data=gorjetas)
valor_gorjeta
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='gorjeta'>

# %% [markdown]
# #### visualmente o valor da gorjeta aumenta conforme aumenta o valor da conta

# %%
gorjetas.shape[0] #mostra quantos registros tempos na base da dados
# Out:
# 244

# %%
print(f'A base de dados contém {gorjetas.shape[0]} de registros')
# Out:
# A base de dados contém 244 de registros

# %%
gorjetas.count() #mostra quais registros não são nulos
# Out:
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## Criando o Campo 'Porcentagem'

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas['valor_da_conta']

# %%
gorjetas.head(5)
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas.porcentagem = gorjetas.porcentagem.round(3)

# %%
gorjetas
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# ..              ...      ...       ...           ...         ...
# 239           29.03     5.92       Não        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
# 242           17.82     1.75       Não        Sábado      Jantar
# 243           18.78     3.00       Não        Quinta      Jantar
#
#      total_de_pessoas  porcentagem
# 0                   2        0.059
# 1                   3        0.161
# 2                   3        0.167
# 3                   2        0.140
# ...

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# #### visualmente o valor da conta não é proporcional ao valor da gorjeta

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem', kind='line', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# ## Análise 2 - Sobremesa

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2        0.059
# 1                 3        0.161
# 2                 3        0.167
# 3                 2        0.140
# 4                 4        0.147

# %%
gorjetas[gorjetas.sobremesa == 'Sim']
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 56            38.01     3.00       Sim        Sábado      Jantar
# 58            11.24     1.76       Sim        Sábado      Jantar
# 60            20.29     3.21       Sim        Sábado      Jantar
# 61            13.81     2.00       Sim        Sábado      Jantar
# 62            11.02     1.98       Sim        Sábado      Jantar
# ..              ...      ...       ...           ...         ...
# 234           15.53     3.00       Sim        Sábado      Jantar
# 236           12.60     1.00       Sim        Sábado      Jantar
# 237           32.83     1.17       Sim        Sábado      Jantar
# 240           27.18     2.00       Sim        Sábado      Jantar
# 241           22.67     2.00       Sim        Sábado      Jantar
#
#      total_de_pessoas  porcentagem
# 56                  4        0.079
# 58                  2        0.157
# 60                  2        0.158
# 61                  2        0.145
# ...

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085093
# min          3.070000   1.000000          1.000000     0.036000
# 25%         13.420000   2.000000          2.000000     0.107000
# 50%         17.920000   3.000000          2.000000     0.154000
# 75%         26.860000   3.680000          3.000000     0.195000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159331
# std          8.255582    1.377190          1.017984     0.039949
# min          7.250000    1.000000          1.000000     0.057000
# 25%         13.325000    2.000000          2.000000     0.136500
# 50%         17.590000    2.740000          2.000000     0.156000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.292000

# %%
sns.catplot(x='sobremesa', y='gorjeta', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', col='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', col='sobremesa', data=gorjetas) #sem o hue o gráfico fica todo da mesma cor

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', col='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='sobremesa', col='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='sobremesa', col='sobremesa', kind='line', data=gorjetas)

# %% [markdown]
# #### visualmente, existe uma diferença no valor da gorjeta daqueles que pediram, ou não, sobremesa

# %% [markdown]
# ## Teste de Hipótese

# %% [markdown]
# #### H<sup>null</sup> (hipótese nula)
#
# ##### A distribuição da taxa da gorjeta é a mesma nos dois grupos
#
# #### H<sup>alt</sup> (hipótese alternativa)
#
# ##### A distribuição da taxa da gorjeta não é a mesma nos dois grupos

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query("sobremesa == 'Sim'").porcentagem
sobremesa
# Out:
# 56     0.079
# 58     0.157
# 60     0.158
# 61     0.145
# 62     0.180
#        ...
# 234    0.193
# 236    0.079
# 237    0.036
# 240    0.074
# 241    0.088
# Name: porcentagem, Length: 93, dtype: float64

# %%
sem_sobremesa = gorjetas.query("sobremesa == 'Não'").porcentagem
sem_sobremesa
# Out:
# 0      0.059
# 1      0.161
# 2      0.167
# 3      0.140
# 4      0.147
#        ...
# 235    0.124
# 238    0.130
# 239    0.204
# 242    0.098
# 243    0.160
# Name: porcentagem, Length: 151, dtype: float64

# %%
ranksums(sobremesa, sem_sobremesa) #para aceitar a hipotese alternativa o pvalue tem que ser igual ou menor do que 0.05,
                                   #nesse caso iremos continuar com a hipótese nula
# Out:
# RanksumsResult(statistic=-0.5714773989576214, pvalue=0.5676760764441404)

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print(f'O valor do pvalue é {r.pvalue}')
# Out:
# O valor do pvalue é 0.5676760764441404

# %% [markdown]
# ### Resultado:
# #### H<sup>null</sup> (hipótese alternativa)
#
# ##### A distribuição da taxa da gorjeta é a mesma nos dois grupos

# %% [markdown]
# ## Análise 3 - Dia da Semana

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2        0.059
# 1                 3        0.161
# 2                 3        0.167
# 3                 2        0.140
# 4                 4        0.147

# %%
gorjetas.dia_da_semana.unique()
# Out:
# array(['Domingo', 'Sábado', 'Quinta', 'Sexta'], dtype=object)

# %%
sns.catplot(x='dia_da_semana', y='valor_da_conta', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean()
media_geral_gorjetas
# Out:
# 2.9982786885245902

# %%
print(f'A média geral das gorjetas é {media_geral_gorjetas:.3f}')
# Out:
# A média geral das gorjetas é 2.998

# %%
gorjetas.groupby(['dia_da_semana']).mean()
# Out:
#                valor_da_conta   gorjeta  total_de_pessoas  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132          2.842105     0.166921
# Quinta              17.682742  2.771452          2.451613     0.161274
# Sexta               17.151579  2.734737          2.105263     0.170000
# Sábado              20.441379  2.993103          2.517241     0.153149

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']] #[[]] usa-se colchetes pra escrever
                                                                                         #só as info que queremos
# Out:
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166921
# Quinta              17.682742  2.771452     0.161274
# Sexta               17.151579  2.734737     0.170000
# Sábado              20.441379  2.993103     0.153149

# %%
print('Frequência dos dias da semana')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias da semana
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ## Teste de Hipótese

# %% [markdown]
# ### H<sup>null</sup>
# #### A distribuição do valor da conta é igual no sábado e no domingo
# ### H<sup>alt</sup>
# ####  A distribuição do valor da conta não é igual no sábado e no domingo

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta
valor_conta_domingo
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 186    20.90
# 187    30.46
# 188    18.15
# 189    23.10
# 190    15.69
# Name: valor_da_conta, Length: 76, dtype: float64

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta 
valor_conta_sabado.head()
# Out:
# 19    20.65
# 20    17.92
# 21    20.29
# 22    15.77
# 23    39.42
# Name: valor_da_conta, dtype: float64

# %%
r2 = ranksums(valor_conta_domingo, valor_conta_sabado)
print(f'O valor do pvalue é {r2.pvalue}')
# Out:
# O valor do pvalue é 0.3576728477868443

# %% [markdown]
# ### Resultado
# ### H<sup>null</sup>
# #### A distribuição do valor da conta é igual no sábado e no domingo

# %% [markdown]
# ## Análise 4 - Hora do Dia

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2        0.059
# 1                 3        0.161
# 2                 3        0.167
# 3                 2        0.140
# 4                 4        0.147

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', kind='swarm', data=gorjetas)

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
sns.distplot(almoco)
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Density'>

# %%
sns.distplot(almoco, kde=False)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
jantar = gorjetas.query("hora_do_dia == 'Jantar'").valor_da_conta

# %%
sns.distplot(jantar)
# Out:
# <AxesSubplot:xlabel='valor_da_conta', ylabel='Density'>

# %%
sns.distplot(jantar, kde=False)
# Out:
# C:\Users\Dell Inspiron\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta','gorjeta','porcentagem']]
# Out:
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.164132
# Jantar            20.797159  3.102670     0.159534

# %% [markdown]
# ### Teste de Hipótese

# %% [markdown]
# ### H<sup>null</sup>
# #### A distribuição do valor da conta é igual no jantar e no almoço
# ### H<sup>alt</sup>
# ####  A distribuição do valor da conta não é igual no jantar e no almoço

# %%
r3 = ranksums(jantar, almoco)
r3
# Out:
# RanksumsResult(statistic=3.2438872807262955, pvalue=0.0011791039723641672)

# %%
print(f'O valor do pvalue é {r3.pvalue}')
# Out:
# O valor do pvalue é 0.0011791039723641672

# %% [markdown]
# ### Resultado
# ### H<sup>alt</sup>
# ####  A distribuição do valor da conta não é igual no jantar e no almoço

# %% [markdown]
# ### Teste de Hipótese
# ### H<sup>null</sup>
# #### A distribuição da taxa da gorjeta é igual no jantar e no almoço
# ### H<sup>alt</sup>
# ####  A distribuição da taxa da gorjeta não é igual no jantar e no almoço

# %%
porcentagem_almoco = gorjetas.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjetas.query("hora_do_dia == 'Jantar'").porcentagem

# %%
r4 = ranksums(porcentagem_almoco, porcentagem_jantar)
r4
# Out:
# RanksumsResult(statistic=1.1996415076212619, pvalue=0.23027859883366675)

# %% [markdown]
# #### Resultado
# ### H<sup>null</sup>
# #### A distribuição da taxa da gorjeta é igual no jantar e no almoço

# %%
print(f'O valor do pvalue é {r4.pvalue}')
# Out:
# O valor do pvalue é 0.23027859883366675
